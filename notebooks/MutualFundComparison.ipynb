# %%
import pandas as pd

import quant as qt

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
qt.plot.set_plot_options()

# %% [markdown]
# # Compare many against the benchmark

# %%
qt.api.mf_list(filter=["Parag", "Flexi", "Direct", "Growth"])
# Out:
#        schemeCode                                         schemeName  \
# 16890      122639  Parag Parikh Flexi Cap Fund - Direct Plan - Gr...
#
#          isinGrowth isinDivReinvestment
# 16890  INF879O01027                None

# %%
qt.api.mf_list(filter=["SBI", "Large|Flexi|Focused", "Direct", "Growth"])
# Out:
#        schemeCode                                       schemeName  \
# 14536      119598           SBI Large Cap FUND-DIRECT PLAN -GROWTH
# 14654      119718  SBI Flexicap Fund - DIRECT PLAN - Growth Option
# 14657      119721     SBI LARGE & MIDCAP FUND -DIRECT PLAN -Growth
# 14661      119727           SBI FOCUSED FUND - DIRECT PLAN -GROWTH
#
#          isinGrowth isinDivReinvestment
# 14536  INF200K01QX4                None
# 14654  INF200K01UG1                None
# 14657  INF200K01UJ5                None
# 14661  INF200K01RJ1                None

# %%
qt.api.mf_list(filter=["ICICI", "Value", "Direct", "Growth"])
# Out:
#        schemeCode                                         schemeName  \
# 15210      120323  ICICI Prudential Value Fund (erstwhile Value D...
# 35785      152365  ICICI Prudential Nifty50 Value 20 Index Fund -...
# 36298      152936  ICICI Prudential Nifty200 Value 30 Index Fund ...
#
#          isinGrowth isinDivReinvestment
# 15210  INF109K012K1                None
# 35785  INF109KC16T3                None
# 36298  INF109KC13X2                None

# %%
vehicles = (
    pd.DataFrame.quant.ticker(
        [
            "INF879O01027",
            "INF200K01UG1",
            "INF200K01QX4",
            "INF200K01UJ5",
            "INF200K01RJ1",
            "INF109K012K1",
        ]
    )
    .quant.palign()
    .quant.to_returns()
    .quant.rename(
        [
            "Parag Parikh Flexi",
            "SBI Flexi",
            "SBI Large",
            "SBI Large&Mid",
            "SBI Focused",
            "ICICI Value",
        ]
    )
)
vehicles.quant.describe()
# Out:
#                  Parag Parikh Flexi            SBI Flexi            SBI Large  \
# Start Date      2018-01-02 00:00:00  2018-01-02 00:00:00  2018-01-02 00:00:00
# End Date        2025-11-28 00:00:00  2025-11-28 00:00:00  2025-11-28 00:00:00
# Num Points                     1944                 1944                 1944
# Missing Values                    0                    0                    0
# Frequency           1 days 00:00:00      1 days 00:00:00      1 days 00:00:00
# Min                       -0.085638            -0.118654             -0.12876
# Max                        0.061542             0.066724             0.077286
# Mean                       0.000741             0.000521             0.000554
#
#                       SBI Large&Mid          SBI Focused          ICICI Value
# Start Date      2018-01-02 00:00:00  2018-01-02 00:00:00  2018-01-02 00:00:00
# End Date        2025-11-28 00:00:00  2025-11-28 00:00:00  2025-11-28 00:00:00
# Num Points                     1944                 1944                 1944
# Missing Values                    0                    0                    0
# Frequency           1 days 00:00:00      1 days 00:00:00      1 days 00:00:00
# Min                       -0.120703            -0.120607            -0.098147
# Max                        0.059878             0.052978             0.078603
# Mean                       0.000627             0.000602             0.000695

# %%
bmk = pd.DataFrame.quant.ticker("^NSEI").quant.to_returns()
bmk.quant.describe()
# Out:
# Ticker                        ^NSEI
# Start Date      2007-09-18 00:00:00
# End Date        2025-12-01 00:00:00
# Num Points                     4465
# Missing Values                    0
# Frequency           1 days 00:00:00
# Min                       -0.129805
# Max                        0.177441
# Mean                        0.00048

# %%
df = pd.concat([vehicles, bmk], axis=1).quant.ralign()
qt.analytics.perf_report(df[vehicles.columns], bmk=df[bmk.columns])
# Out:
# Start date: 2018-01-03
# End date: 2025-11-28
# <style type="text/css">
# #T_16c49_row0_col2 {
#   background-color: #bae394;
#   color: #000000;
# }
# #T_16c49_row0_col3 {
#   background-color: #fffac0;
#   color: #000000;
# }
# #T_16c49_row0_col8 {
#   background-color: #68be71;
#   color: #000000;
# }
# #T_16c49_row1_col2 {
#   background-color: #006536;
#   color: #f1f1f1;
# }
# #T_16c49_row1_col3, #T_16c49_row2_col3, #T_16c49_row3_col3 {
#   background-color: #fee289;
#   color: #000000;
# }
# #T_16c49_row1_col8 {
#   background-color: #005730;
#   color: #f1f1f1;
# }
# #T_16c49_row2_col2 {
#   background-color: #005830;
#   color: #f1f1f1;
# }
# #T_16c49_row2_col8, #T_16c49_row7_col2 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_16c49_row3_col2 {
#   background-color: #005e33;
#   color: #f1f1f1;
# }
# #T_16c49_row3_col8 {
#   background-color: #389f55;
#   color: #f1f1f1;
# }
# #T_16c49_row4_col2, #T_16c49_row26_col8 {
#   background-color: #afde8f;
#   color: #000000;
# }
# #T_16c49_row4_col3 {
#   background-color: #860026;
#   color: #f1f1f1;
# }
# #T_16c49_row4_col8 {
#   background-color: #b1df90;
#   color: #000000;
# }
# #T_16c49_row5_col2, #T_16c49_row5_col8 {
#   background-color: #cfec9e;
#   color: #000000;
# }
# #T_16c49_row5_col3, #T_16c49_row6_col3, #T_16c49_row7_col3 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_16c49_row6_col2 {
#   background-color: #0a703a;
#   color: #f1f1f1;
# }
# #T_16c49_row6_col8, #T_16c49_row9_col2 {
#   background-color: #69bf72;
#   color: #000000;
# }
# #T_16c49_row7_col8 {
#   background-color: #2e924c;
#   color: #f1f1f1;
# }
# #T_16c49_row8_col2 {
#   background-color: #1a7d40;
#   color: #f1f1f1;
# }
# #T_16c49_row8_col3 {
#   background-color: #fec05b;
#   color: #000000;
# }
# #T_16c49_row8_col8 {
#   background-color: #8ed082;
#   color: #000000;
# }
# #T_16c49_row9_col3 {
#   background-color: #d51020;
#   color: #f1f1f1;
# }
# #T_16c49_row9_col8, #T_16c49_row12_col2, #T_16c49_row18_col8 {
#   background-color: #9ad587;
#   color: #000000;
# }
# #T_16c49_row10_col2, #T_16c49_row10_col8 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_16c49_row10_col3 {
#   background-color: #ffe691;
#   color: #000000;
# }
# #T_16c49_row11_col2 {
#   background-color: #8dcf81;
#   color: #000000;
# }
# #T_16c49_row11_col3, #T_16c49_row12_col3 {
#   background-color: #fed572;
#   color: #000000;
# }
# #T_16c49_row11_col8 {
#   background-color: #e8f6ae;
#   color: #000000;
# }
# #T_16c49_row12_col8 {
#   background-color: #daf0a4;
#   color: #000000;
# }
# #T_16c49_row13_col2 {
#   background-color: #6bc072;
#   color: #000000;
# }
# #T_16c49_row13_col3 {
#   background-color: #fecf6b;
#   color: #000000;
# }
# #T_16c49_row13_col8 {
#   background-color: #c7e89a;
#   color: #000000;
# }
# #T_16c49_row14_col2, #T_16c49_row24_col2, #T_16c49_row24_col8 {
#   background-color: #f0f9b4;
#   color: #000000;
# }
# #T_16c49_row14_col3 {
#   background-color: #950026;
#   color: #f1f1f1;
# }
# #T_16c49_row14_col8, #T_16c49_row25_col2 {
#   background-color: #f3fab6;
#   color: #000000;
# }
# #T_16c49_row15_col2 {
#   background-color: #6fc174;
#   color: #000000;
# }
# #T_16c49_row15_col3 {
#   background-color: #fff7b9;
#   color: #000000;
# }
# #T_16c49_row15_col8, #T_16c49_row22_col2 {
#   background-color: #81ca7d;
#   color: #000000;
# }
# #T_16c49_row16_col2 {
#   background-color: #2f934d;
#   color: #f1f1f1;
# }
# #T_16c49_row16_col3, #T_16c49_row17_col3 {
#   background-color: #fff0a7;
#   color: #000000;
# }
# #T_16c49_row16_col8 {
#   background-color: #a2d88a;
#   color: #000000;
# }
# #T_16c49_row17_col2 {
#   background-color: #369d54;
#   color: #f1f1f1;
# }
# #T_16c49_row17_col8 {
#   background-color: #93d284;
#   color: #000000;
# }
# #T_16c49_row18_col2 {
#   background-color: #2c8f4b;
#   color: #f1f1f1;
# }
# #T_16c49_row18_col3 {
#   background-color: #fd903d;
#   color: #000000;
# }
# #T_16c49_row19_col2 {
#   background-color: #c9e99c;
#   color: #000000;
# }
# #T_16c49_row19_col3 {
#   background-color: #c40524;
#   color: #f1f1f1;
# }
# #T_16c49_row19_col8 {
#   background-color: #d2eda0;
#   color: #000000;
# }
# #T_16c49_row20_col2 {
#   background-color: #f9fdc7;
#   color: #000000;
# }
# #T_16c49_row20_col3 {
#   background-color: #fff0a8;
#   color: #000000;
# }
# #T_16c49_row20_col8 {
#   background-color: #f8fcc0;
#   color: #000000;
# }
# #T_16c49_row21_col2 {
#   background-color: #77c679;
#   color: #000000;
# }
# #T_16c49_row21_col3, #T_16c49_row22_col3 {
#   background-color: #feda78;
#   color: #000000;
# }
# #T_16c49_row21_col8 {
#   background-color: #cbea9c;
#   color: #000000;
# }
# #T_16c49_row22_col8 {
#   background-color: #a9db8c;
#   color: #000000;
# }
# #T_16c49_row23_col2 {
#   background-color: #72c376;
#   color: #000000;
# }
# #T_16c49_row23_col3, #T_16c49_row28_col3 {
#   background-color: #fed16e;
#   color: #000000;
# }
# #T_16c49_row23_col8 {
#   background-color: #b9e294;
#   color: #000000;
# }
# #T_16c49_row24_col3 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_16c49_row25_col3 {
#   background-color: #ffeda1;
#   color: #000000;
# }
# #T_16c49_row25_col8 {
#   background-color: #edf8b2;
#   color: #000000;
# }
# #T_16c49_row26_col2 {
#   background-color: #3fa95c;
#   color: #f1f1f1;
# }
# #T_16c49_row26_col3, #T_16c49_row27_col3 {
#   background-color: #fee187;
#   color: #000000;
# }
# #T_16c49_row27_col2 {
#   background-color: #51b365;
#   color: #f1f1f1;
# }
# #T_16c49_row27_col8 {
#   background-color: #a4d98a;
#   color: #000000;
# }
# #T_16c49_row28_col2 {
#   background-color: #238443;
#   color: #f1f1f1;
# }
# #T_16c49_row28_col8 {
#   background-color: #7cc87b;
#   color: #000000;
# }
# #T_16c49_row29_col2 {
#   background-color: #d3eda0;
#   color: #000000;
# }
# #T_16c49_row29_col3 {
#   background-color: #8a0026;
#   color: #f1f1f1;
# }
# #T_16c49_row29_col8 {
#   background-color: #d6efa2;
#   color: #000000;
# }
# </style>
# <table id="T_16c49">
#   <caption>Performance Summary</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Statistic</th>
#       <th id="T_16c49_level0_col0" class="col_heading level0 col0" >Excess Return</th>
#       <th id="T_16c49_level0_col1" class="col_heading level0 col1" >Volatility</th>
#       <th id="T_16c49_level0_col2" class="col_heading level0 col2" >Sharpe</th>
#       <th id="T_16c49_level0_col3" class="col_heading level0 col3" >Max Drawdown</th>
#       <th id="T_16c49_level0_col4" class="col_heading level0 col4" >Hit Ratio</th>
#       <th id="T_16c49_level0_col5" class="col_heading level0 col5" >Beta</th>
#       <th id="T_16c49_level0_col6" class="col_heading level0 col6" >Alpha</th>
#       <th id="T_16c49_level0_col7" class="col_heading level0 col7" >Tracking Error</th>
#       <th id="T_16c49_level0_col8" class="col_heading level0 col8" >Information Ratio</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Asset</th>
#       <th class="index_name level1" >Period</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_16c49_level0_row0" class="row_heading level0 row0" rowspan="5">ICICI Value</th>
#       <th id="T_16c49_level1_row0" class="row_heading level1 row0" >01YR</th>
#       <td id="T_16c49_row0_col0" class="data row0 col0" >11.86%</td>
#       <td id="T_16c49_row0_col1" class="data row0 col1" >10.41%</td>
#       <td id="T_16c49_row0_col2" class="data row0 col2" >1.14</td>
#       <td id="T_16c49_row0_col3" class="data row0 col3" >-9.55%</td>
#       <td id="T_16c49_row0_col4" class="data row0 col4" >54.58%</td>
#       <td id="T_16c49_row0_col5" class="data row0 col5" >0.83</td>
#       <td id="T_16c49_row0_col6" class="data row0 col6" >4.71%</td>
#       <td id="T_16c49_row0_col7" class="data row0 col7" >2.66%</td>
#       <td id="T_16c49_row0_col8" class="data row0 col8" >1.77</td>
#     </tr>
#     <tr>
#       <th id="T_16c49_level1_row1" class="row_heading level1 row1" >02YR</th>
#       <td id="T_16c49_row1_col0" class="data row1 col0" >21.87%</td>
#       <td id="T_16c49_row1_col1" class="data row1 col1" >10.97%</td>
#       <td id="T_16c49_row1_col2" class="data row1 col2" >1.99</td>
#       <td id="T_16c49_row1_col3" class="data row1 col3" >-
# <style type="text/css">
# #T_7d20d_row0_col2 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_7d20d_row0_col3 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_7d20d_row1_col2 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_7d20d_row1_col3, #T_7d20d_row2_col3 {
#   background-color: #ffe58f;
#   color: #000000;
# }
# #T_7d20d_row2_col2 {
#   background-color: #2c8f4b;
#   color: #f1f1f1;
# }
# #T_7d20d_row3_col2 {
#   background-color: #00512e;
#   color: #f1f1f1;
# }
# #T_7d20d_row3_col3 {
#   background-color: #fedc7c;
#   color: #000000;
# }
# #T_7d20d_row4_col2 {
#   background-color: #f3fab6;
#   color: #000000;
# }
# #T_7d20d_row4_col3 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7d20d">
#   <caption>Benchmark Performance Summary</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Statistic</th>
#       <th id="T_7d20d_level0_col0" class="col_heading level0 col0" >Excess Return</th>
#       <th id="T_7d20d_level0_col1" class="col_heading level0 col1" >Volatility</th>
#       <th id="T_7d20d_level0_col2" class="col_heading level0 col2" >Sharpe</th>
#       <th id="T_7d20d_level0_col3" class="col_heading level0 col3" >Max Drawdown</th>
#       <th id="T_7d20d_level0_col4" class="col_heading level0 col4" >Hit Ratio</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Asset</th>
#       <th class="index_name level1" >Period</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7d20d_level0_row0" class="row_heading level0 row0" rowspan="5">^NSEI</th>
#       <th id="T_7d20d_level1_row0" class="row_heading level1 row0" >01YR</th>
#       <td id="T_7d20d_row0_col0" class="data row0 col0" >8.59%</td>
#       <td id="T_7d20d_row0_col1" class="data row0 col1" >12.09%</td>
#       <td id="T_7d20d_row0_col2" class="data row0 col2" >0.71</td>
#       <td id="T_7d20d_row0_col3" class="data row0 col3" >-10.84%</td>
#       <td id="T_7d20d_row0_col4" class="data row0 col4" >50.79%</td>
#     </tr>
#     <tr>
#       <th id="T_7d20d_level1_row1" class="row_heading level1 row1" >02YR</th>
#       <td id="T_7d20d_row1_col0" class="data row1 col0" >15.77%</td>
#       <td id="T_7d20d_row1_col1" class="data row1 col1" >13.05%</td>
#       <td id="T_7d20d_row1_col2" class="data row1 col2" >1.21</td>
#       <td id="T_7d20d_row1_col3" class="data row1 col3" >-15.77%</td>
#       <td id="T_7d20d_row1_col4" class="data row1 col4" >54.37%</td>
#     </tr>
#     <tr>
#       <th id="T_7d20d_level1_row2" class="row_heading level1 row2" >03YR</th>
#       <td id="T_7d20d_row2_col0" class="data row2 col0" >12.88%</td>
#       <td id="T_7d20d_row2_col1" class="data row2 col1" >12.07%</td>
#       <td id="T_7d20d_row2_col2" class="data row2 col2" >1.07</td>
#       <td id="T_7d20d_row2_col3" class="data row2 col3" >-15.77%</td>
#       <td id="T_7d20d_row2_col4" class="data row2 col4" >54.63%</td>
#     </tr>
#     <tr>
#       <th id="T_7d20d_level1_row3" class="row_heading level1 row3" >05YR</th>
#       <td id="T_7d20d_row3_col0" class="data row3 col0" >16.74%</td>
#       <td id="T_7d20d_row3_col1" class="data row3 col1" >14.12%</td>
#       <td id="T_7d20d_row3_col2" class="data row3 col2" >1.19</td>
#       <td id="T_7d20d_row3_col3" class="data row3 col3" >-17.23%</td>
#       <td id="T_7d20d_row3_col4" class="data row3 col4" >54.76%</td>
#     </tr>
#     <tr>
#       <th id="T_7d20d_level1_row4" class="row_heading level1 row4" >SI</th>
#       <td id="T_7d20d_row4_col0" class="data row4 col0" >13.37%</td>
#       <td id="T_7d20d_row4_col1" class="data row4 col1" >17.13%</td>
#       <td id="T_7d20d_row4_col2" class="data row4 col2" >0.78</td>
#       <td id="T_7d20d_row4_col3" class="data row4 col3" >-38.44%</td>
#       <td id="T_7d20d_row4_col4" class="data row4 col4" >54.41%</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_cbb72_row0_col2 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_cbb72_row1_col2 {
#   background-color: #c1161b;
#   color: #f1f1f1;
# }
# #T_cbb72_row2_col2 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_cbb72_row3_col2 {
#   background-color: #9d0d14;
#   color: #f1f1f1;
# }
# #T_cbb72_row4_col2 {
#   background-color: #fcb89e;
#   color: #000000;
# }
# #T_cbb72_row5_col2 {
#   background-color: #860811;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_cbb72">
#   <caption>Drawdowns</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cbb72_level0_col0" class="col_heading level0 col0" >Start Date</th>
#       <th id="T_cbb72_level0_col1" class="col_heading level0 col1" >End Date</th>
#       <th id="T_cbb72_level0_col2" class="col_heading level0 col2" >Drawdown</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cbb72_level0_row0" class="row_heading level0 row0" >Parag Parikh Flexi</th>
#       <td id="T_cbb72_row0_col0" class="data row0 col0" >2020-02-13</td>
#       <td id="T_cbb72_row0_col1" class="data row0 col1" >2020-03-24</td>
#       <td id="T_cbb72_row0_col2" class="data row0 col2" >-31.20%</td>
#     </tr>
#     <tr>
#       <th id="T_cbb72_level0_row1" class="row_heading level0 row1" >SBI Flexi</th>
#       <td id="T_cbb72_row1_col0" class="data row1 col0" >2020-01-24</td>
#       <td id="T_cbb72_row1_col1" class="data row1 col1" >2020-03-23</td>
#       <td id="T_cbb72_row1_col2" class="data row1 col2" >-35.80%</td>
#     </tr>
#     <tr>
#       <th id="T_cbb72_level0_row2" class="row_heading level0 row2" >SBI Large</th>
#       <td id="T_cbb72_row2_col0" class="data row2 col0" >2020-01-16</td>
#       <td id="T_cbb72_row2_col1" class="data row2 col1" >2020-03-23</td>
#       <td id="T_cbb72_row2_col2" class="data row2 col2" >-37.08%</td>
#     </tr>
#     <tr>
#       <th id="T_cbb72_level0_row3" class="row_heading level0 row3" >SBI Large&Mid</th>
#       <td id="T_cbb72_row3_col0" class="data row3 col0" >2020-02-20</td>
#       <td id="T_cbb72_row3_col1" class="data row3 col1" >2020-03-23</td>
#       <td id="T_cbb72_row3_col2" class="data row3 col2" >-36.43%</td>
#     </tr>
#     <tr>
#       <th id="T_cbb72_level0_row4" class="row_heading level0 row4" >SBI Focused</th>
#       <td id="T_cbb72_row4_col0" class="data row4 col0" >2020-02-20</td>
#       <td id="T_cbb72_row4_col1" class="data row4 col1" >2020-03-23</td>
#       <td id="T_cbb72_row4_col2" class="data row4 col2" >-32.74%</td>
#     </tr>
#     <tr>
#       <th id="T_cbb72_level0_row5" class="row_heading level0 row5" >ICICI Value</th>
#       <td id="T_cbb72_row5_col0" class="data row5 col0" >2018-09-07</td>
#       <td id="T_cbb72_row5_col1" class="data row5 col1" >2020-03-23</td>
#       <td id="T_cbb72_row5_col2" class="data row5 col2" >-36.70%</td>
#     </tr>
#   </tbody>
# </table>

# %%
qt.plot.heatmap(df.corr())
# Out:
# <Axes: >

# %% [markdown]
# # Portfolio Construction

# %%
portfolio = qt.Portfolio(vehicles.iloc[:, :])
portfolio
# Out:
# Portfolio(assets=6)
# Period: 2018-01-02 to 2025-11-28
# Rebalance: M
# Assets: Parag Parikh Flexi, SBI Flexi, SBI Large... and 3 more

# %%
portfolio.kelly_weights()
# Out:
# Parag Parikh Flexi    1.000000e+00
# SBI Flexi             8.534840e-16
# SBI Large             5.481726e-16
# SBI Large&Mid         1.387779e-16
# SBI Focused           2.636780e-16
# ICICI Value           0.000000e+00
# dtype: float64

# %%
portfolio.mvo_weights()
# Out:
# Parag Parikh Flexi    1.000000e+00
# SBI Flexi             0.000000e+00
# SBI Large             6.938894e-18
# SBI Large&Mid         1.769418e-16
# SBI Focused           0.000000e+00
# ICICI Value           0.000000e+00
# dtype: float64

# %%
portfolio.risk_budget_weights()
# Out:
# Parag Parikh Flexi    0.194702
# SBI Flexi             0.156363
# SBI Large             0.155127
# SBI Large&Mid         0.148606
# SBI Focused           0.168047
# ICICI Value           0.177156
# dtype: float64
